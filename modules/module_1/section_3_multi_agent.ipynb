# %% [markdown]
# # Module 1, Section 3: Multi-Agent Architecture
#
#
# In this section, you'll learn to build a multi-agent customer support system using:
# - **Specialized sub-agents** focused on distinct domains (database vs. documents)
# - **Supervisor agent** that smartly routes queries to the right expert
# - **Tool wrapping**, enabling the supervisor to delegate tasks to sub-agents as tools
# - **Testing with LangSmith traces** to see multi-agent coordination in action
#
# By the end, you'll have a working system with:
# - **Database Agent** for order, product, and customer queries
# - **Documents Agent** for searching product documents and policies
# - **Supervisor** for orchestration and delegation
#
# <div align="center">
#     <img src="../../static/supervisor_agent.png">
# </div>

# %% [markdown]
# ## Setup
#
# Load environment variables:

# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 1. Import Tools
#
# We'll use the tools we created in previous sections, plus new Documents tools for document search:
#
# <div align="center">
#     <img src="../../static/db_rag_tools.png" alt="Schema Diagram">
# </div>
#
# **New:** Semantic Search Tools for Products & Policies
#
# We've added two tools—`search_product_docs` and `search_policy_docs`—that let our agents search over product information and company policies using semantic search (vector database + embeddings). This makes it easy to answer user questions about docs, warranty, and returns with smart retrieval.

# %%
# Import database tools (from Section 1)
from tools.database import get_order_status, get_order_items, get_product_info

# Import Documents tools (new in Section 3)
from tools.documents import search_product_docs, search_policy_docs

# %% [markdown]
# Lets test one out:

# %%
result = search_policy_docs.invoke("How long is the warranty on electronics?")
print(result)
# Out:
# [warranty_guide]
# # Warranty Guide
#
# All products purchased from TechHub include manufacturer warranty coverage. This guide explains what's covered, what's not, and how to file a warranty claim.
#
# ## Standard Warranty Coverage
#
# **All Products Include:**
# - 1-year limited manufacturer warranty
# - Coverage begins on the delivery date
# - Covers manufacturing defects in materials and workmanship
# - Hardware component failures under normal use conditions
#
# **What This Means:**
# Your product is guaranteed to be free from defects in materials and workmanship for one year from the date of delivery. If a covered issue occurs during this period, the manufacturer will repair or replace the product at no charge.
#
# ## What's Covered
#
# The manufacturer warranty covers:
#
# ---
#
# [warranty_guide]
# ## How TechHub Can Help
#
# While manufacturers handle warranty service directly, we're here to assist:
#
# - **Proof of Purchase:** We can provide your receipt or invoice for warranty claims
# - **Facilitation:** We can help you connect with the right manufacturer support team
# - **Account History:** We maintain records of your purchases for easy reference
# - **Guidance:** Not sure if your issue is covered? Contact us and we'll help you determine next steps
#
# ## Warranty vs. Return Policy
#
# It's important to understand the difference:
#
# **Return Policy (14-30 days):**
# - For any reason, including buyer's remorse
# - Handled through TechHub
# - Fast resolution (refund within 5-7 business days)
# - May include restocking fee for opened items over $500
#
# **Warranty (1 year+):**
# - For defects and hardware failures only
# - Handled by the manufacturer
# - Longer turnaround time (1-3 weeks)
# - No cost for covered issues

# %% [markdown]
# ## 2. Build Database Agent
#
# Our first specialist: an agent focused on querying structured data from the TechHub database (order status, order items, product info).

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langgraph.checkpoint.memory import MemorySaver
from config import DEFAULT_MODEL

# Initialize model
llm = init_chat_model(DEFAULT_MODEL)

# Create Database Agent
db_agent = create_agent(
    model=llm,
    tools=[get_order_status, get_order_items, get_product_info],
    system_prompt="""You are the database specialist for TechHub customer support.

Your role is to answer queries from a supervisor agent about orders or products using the TechHub database tools you have been provided.
You do NOT interact directly with customers, you only interact with the supervisor agent.

Capabilities: Look up and report order status, order details (items, quantities), product prices, and product availability.

Instructions:
- Always retrieve answers directly from the database using the available tools.
- If information is missing or not found, say so clearly.
- Do NOT make assumptions or provide information not explicitly present in the database.

Be accurate, concise, and specific in your replies.""",
    checkpointer=MemorySaver(),
)

# %% [markdown]
# Let's test the Database Agent:

# %%
import uuid

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}


result = db_agent.invoke(
    {
        "messages": [
            {"role": "user", "content": "What items were in order ORD-2024-0063?"}
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What items were in order ORD-2024-0063?
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_01CubD6jnUk6LkiyyrUvBzsA', 'input': {'order_id': 'ORD-2024-0063'}, 'name': 'get_order_items', 'type': 'tool_use'}]
# Tool Calls:
#   get_order_items (toolu_01CubD6jnUk6LkiyyrUvBzsA)
#  Call ID: toolu_01CubD6jnUk6LkiyyrUvBzsA
#   Args:
#     order_id: ORD-2024-0063
# ================================= Tool Message =================================
# Name: get_order_items
#
# Items in order ORD-2024-0063:
# - Product ID: TECH-MON-006, Quantity: 1, Price: $543.74
#
# ================================== Ai Message ==================================
#
# Order ORD-2024-0063 contained the following item:
#
# - **Product ID:** TECH-MON-006
# - **Quantity:** 1
# - **Price:** $543.74
#
# If you need the product name or additional details about this item, I can look that up using the product ID.

# %% [markdown]
# ## 3. Build Documents Agent
#
# Our second specialist: an agent focused on searching product documentation and policies.

# %%
# Create Documents Agent
docs_agent = create_agent(
    model=llm,
    tools=[search_product_docs, search_policy_docs],
    system_prompt="""You are the company policy and product information specialist for TechHub customer support.

Your role is to answer queries from a supervisor agent about product specifications, features, compatibility, 
policies (returns, warranties, shipping), and setup instructions given the tools you have been provided.
You do NOT interact directly with customers, you only interact with the supervisor agent.

Capabilities: Search product documentation and company policies.

Instructions:
- Always search the documentation to provide accurate, detailed information.
- If information is missing or not found, say so clearly.
- Do NOT make assumptions or provide information not explicitly present in the documentation.

Be accurate, concise, and specific in your replies.""",
    checkpointer=MemorySaver(),
)

# %% [markdown]
# Let's test the Documents Agent:

# %%
thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

result = docs_agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "What's your return policy for opened electronics?",
            }
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What's your return policy for opened electronics?
# ================================== Ai Message ==================================
#
# [{'text': "I'll search for information about our return policy for opened electronics.", 'type': 'text'}, {'id': 'toolu_01KTM1dyV5JyRbR6AJpQ8vDn', 'input': {'query': 'return policy opened electronics'}, 'name': 'search_policy_docs', 'type': 'tool_use'}]
# Tool Calls:
#   search_policy_docs (toolu_01KTM1dyV5JyRbR6AJpQ8vDn)
#  Call ID: toolu_01KTM1dyV5JyRbR6AJpQ8vDn
#   Args:
#     query: return policy opened electronics
# ================================= Tool Message =================================
# Name: search_policy_docs
#
# [return_policy]
# # Return Policy
#
# At TechHub, we want you to be completely satisfied with your purchase. If you're not happy with your order, we accept returns within our specified return windows.
#
# ## Return Windows
#
# **Unopened Electronics**
# - 30 days from delivery date
# - All original packaging and seals must be intact
# - Full refund to original payment method
#
# **Opened Electronics**
# - 14 days from delivery date
# - Product must be in good working condition
# - All accessories, cables, and documentation must be included
# - Original packaging helpful but not required
#
# **All Other Items**
# - 30 days from delivery date
# - Must be in original condition
#
# ## Condition Requirements
#
# To qualify for a return, items must meet the following conditions:
#
# ---
#
# [return_policy]
# **All Other Items**
# - 30 days from delivery date
# - Must be in original condition
#
# ## Condition Requirements
#
# To qualify for a return, items must meet the following conditions:
#
# - Product is in good working condition with no physical damage
# - All original accessories are included (power adapters, cables, manuals, etc.)
# - No signs of misuse or abuse
# - Serial numbers and identification labels are intact
# - For opened items, minimal signs of use are acceptable
#
# ## Non-Returnable Items
#
# The following items cannot be returned:
#
# - Clearance or final sale items (marked as such at checkout)
# - Digital gift cards
# - Downloadable software or digital products
# - Items marked "non-returnable" on the product page
#
# ## Restocking Fees
#
# **No Restocking Fee:**
# - Defective items (manufacturer defects or damage during shipping)
# - Unopened items in original packaging
# - Items under $500
# ================================== Ai Message ==================================
#
# Based on our return policy, here's what applies to **opened electronics**:
#
# **Return Window:** 14 days from delivery date
#
# **Conditions:**
# - Product must be in good working condition
# - All accessories, cables, and documentation must be included
# - Original packaging is helpful but not required
# - Minimal signs of use are acceptable
#
# **Key Requirements:**
# - No physical damage
# - Serial numbers and identification labels must be intact
# - No signs of misuse or abuse
#
# **Restocking Fees:**
# - Items under $500: No restocking fee
# - Items $500 and above: Check if a restocking fee applies
#
# **Non-returnable items** include clearance/final sale items, digital products, and items marked "non-returnable" on the product page.
#
# Is there anything specific about the return policy you'd like clarified?

# %% [markdown]
# ## 4. Build Supervisor Agent
#
# Now we'll create a supervisor agent that coordinates our specialists.
#
# **Key insight:** Sub-agents become *tools* for the supervisor!

# %%
from langchain_core.tools import tool


# Wrap Database Agent as a tool
@tool(
    "database_specialist",
    description="Query TechHub database specialist for order status, order details, product prices, and product availability",
)
def call_database_specialist(query: str) -> str:
    """Call the database specialist subagent.

    Args:
        query: The question to ask the database specialist
    """
    result = db_agent.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].content


# Wrap Documents Agent as a tool
@tool(
    "documentation_specialist",
    description="Query TechHub documentation specialist to search for product specs, policies, warranties, and setup instructions",
)
def call_documentation_specialist(query: str) -> str:
    """Call the documentation specialist subagent.

    Args:
        query: The question to ask the documentation specialist
    """
    result = docs_agent.invoke({"messages": [{"role": "user", "content": query}]})
    return result["messages"][-1].content

# %% [markdown]
# **Key insight:** The tool descriptions help the supervisor decide when to use each tool, so make them clear and specific. We return only the sub-agent’s final response, as the supervisor doesn’t need to see intermediate reasoning or tool calls.

# %% [markdown]
# Now, lets create the supervisor agent!

# %%
# Create Supervisor Agent
supervisor_agent = create_agent(
    model=llm,
    tools=[call_database_specialist, call_documentation_specialist],
    system_prompt="""You are a supervisor agent for TechHub customer support.

Your role is to interact with customers to understand their questions, use the sub-agent tools provided to 
gather information needed to answer their questions, and then provide helpful responses to the customer.

Capabilities:
- Interact with customers to understand their questions
- Use database_specialist to help answer questions about orders (status, details) and products (prices, availability)
- Use documentation_specialist to help answer questions about product specs, policies, warranties, and setup instructions


You can use multiple tools if needed to fully answer the question.
Always provide helpful, accurate, concise, and specific responses to customer questions.""",
    checkpointer=MemorySaver(),
)

# %% [markdown]
# ## 5. Test Simple Routing
#
# Let's test the supervisor with queries that need just ONE specialist:

# %%
print("Query 1: Order status (should route to Database Agent)")

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

result = supervisor_agent.invoke(
    {
        "messages": [
            {"role": "user", "content": "What's the status of order ORD-2025-0030?"}
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
print("\n💡 Check LangSmith traces to see: Supervisor → database_specialist → DB Agent")
# Out:
# Query 1: Order status (should route to Database Agent)
# ================================ Human Message =================================
#
# What's the status of order ORD-2025-0030?
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_012ccZcAHz2Ufxvk8eA37eZB', 'input': {'query': 'What is the status of order ORD-2025-0030?'}, 'name': 'database_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   database_specialist (toolu_012ccZcAHz2Ufxvk8eA37eZB)
#  Call ID: toolu_012ccZcAHz2Ufxvk8eA37eZB
#   Args:
#     query: What is the status of order ORD-2025-0030?
# ================================= Tool Message =================================
# Name: database_specialist
#
# The status of order **ORD-2025-0030** is:
#
# - **Status**: Processing
# - **Order Date**: 2025-10-18
# - **Total Amount**: $240.11
#
# The order is currently being processed and does not have tracking information available yet.
# ================================== Ai Message ==================================
#
# Your order **ORD-2025-0030** is currently in **Processing** status.
#
# **Order Details:**
# - **Order Date:** October 18, 2025
# - **Total Amount:** $240.11
# - **Status:** Processing
#
# Your order is being prepared and processed by our warehouse. Tracking information will be available as soon as your order ships. You should receive a notification with tracking details shortly. If you need any additional information about your order, feel free to ask!
#
# 💡 Check LangSmith traces to see: Supervisor → database_specialist → DB Agent

# %%
print("\nQuery 2: Product question (should route to Documents Agent)")

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

result = supervisor_agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "What's included in the box with the Logitech MX Keys keyboard?",
            }
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
print(
    "\n💡 Check LangSmith traces to see: Supervisor → documentation_specialist → Documents Agent"
)
# Out:
# Query 2: Product question (should route to Documents Agent)
# ================================ Human Message =================================
#
# What's included in the box with the Logitech MX Keys keyboard?
# ================================== Ai Message ==================================
#
# [{'id': 'toolu_01QvNFXDhnxeNYzfYGB2MGdf', 'input': {'query': "Logitech MX Keys keyboard box contents what's included"}, 'name': 'documentation_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   documentation_specialist (toolu_01QvNFXDhnxeNYzfYGB2MGdf)
#  Call ID: toolu_01QvNFXDhnxeNYzfYGB2MGdf
#   Args:
#     query: Logitech MX Keys keyboard box contents what's included
# ================================= Tool Message =================================
# Name: documentation_specialist
#
# Based on the product documentation, here's what's included in the Logitech MX Keys keyboard box:
#
# **Box Contents:**
# - Logitech MX Keys Wireless Keyboard
# - Logitech Bolt USB receiver
# - USB-A to USB-C charging cable (1.5m)
# - User documentation
#
# **Additional Note:** The Logitech Options+ software is available as a free download from logitech.com but is not included in the box.
# ================================== Ai Message ==================================
#
# When you unbox the **Logitech MX Keys keyboard**, you'll find:
#
# 1. **Logitech MX Keys Wireless Keyboard** - the keyboard itself
# 2. **Logitech Bolt USB receiver** - for wireless connectivity
# 3. **USB-A to USB-C charging cable** (1.5m) - for charging the keyboard
# 4. **User documentation** - quick start guides and manuals
#
# **Note:** The Logitech Options+ software is not included in the box but is available as a free download from logitech.com if you want to customize the keyboard settings and features.
#
# Is there anything else you'd like to know about the Logitech MX Keys keyboard?
#
# 💡 Check LangSmith traces to see: Supervisor → documentation_specialist → Documents Agent

# %% [markdown]
# ## 6. Test Multi-Agent Coordination
#
# Now the more interesting part - queries that require BOTH sub-agents!

# %% [markdown]
# **Parallel Execution Example:** Query that requires both Database AND Documents subagents

# %%
print("Query 3: Requires both Database AND Documents agents - parallel")

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

result = supervisor_agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Is the MacBook Air in stock? What type of processor does it have? And if I buy it, what's the return policy?",
            }
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
print("\n💡 Check LangSmith traces to see the parallel flow")
# Out:
# Query 3: Requires both Database AND Documents agents - parallel
# ================================ Human Message =================================
#
# Is the MacBook Air in stock? What type of processor does it have? And if I buy it, what's the return policy?
# ================================== Ai Message ==================================
#
# [{'text': "I'll help you find information about the MacBook Air's availability, processor, and our return policy.", 'type': 'text'}, {'id': 'toolu_01F9pRrsYkYwV9ULevFjPabT', 'input': {'query': 'Is MacBook Air in stock? What is the availability?'}, 'name': 'database_specialist', 'type': 'tool_use'}, {'id': 'toolu_01JQiGMM4ea82FL6LhdzDqgb', 'input': {'query': 'MacBook Air processor specifications'}, 'name': 'documentation_specialist', 'type': 'tool_use'}, {'id': 'toolu_019Za9jimbPWZWoY5RS5JSbi', 'input': {'query': 'return policy'}, 'name': 'documentation_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   database_specialist (toolu_01F9pRrsYkYwV9ULevFjPabT)
#  Call ID: toolu_01F9pRrsYkYwV9ULevFjPabT
#   Args:
#     query: Is MacBook Air in stock? What is the availability?
#   documentation_specialist (toolu_01JQiGMM4ea82FL6LhdzDqgb)
#  Call ID: toolu_01JQiGMM4ea82FL6LhdzDqgb
#   Args:
#     query: MacBook Air processor specifications
#   documentation_specialist (toolu_019Za9jimbPWZWoY5RS5JSbi)
#  Call ID: toolu_019Za9jimbPWZWoY5RS5JSbi
#   Args:
#     query: return policy
# ================================= Tool Message =================================
# Name: database_specialist
#
# Yes, the **MacBook Air M2 (13-inch, 256GB)** is currently **in stock**.
#
# **Details:**
# - **Product ID:** TECH-LAP-001
# - **Category:** Laptops
# - **Price:** $1,199.00
# - **Availability Status:** In Stock
# ================================= Tool Message =================================
# Name: documentation_specialist
#
# Based on the documentation, here are the MacBook Air processor specifications:
#
# ## MacBook Air M2 (13-inch, 256GB)
#
# **Processor:** Apple M2 chip
#
# Unfortunately, the detailed processor specifications for the M2 chip (such as CPU core count, GPU core count, etc.) are not fully displayed in the available documentation excerpt.
#
# For comparison, I also found:
#
# ## MacBook Pro M3 (14-inch, 512GB) - For Reference
#
# **Processor:** Apple M3 chip with:
# - 8-core CPU (4 performance cores, 4 efficiency cores)
# - 10-core GPU
# - Hardware-accelerated ray tracing
#
# The MacBook Air M2 also features excellent performance characteristics, including:
# - Up to 18 hours of battery life
# - Fanless design for silent operation
# - Suitable for web browsing, video editing, and general professional work
#
# If you need more detailed specifications about the M2 processor core configuration, clock speeds, or other technical details, please let me know and I can search for more specific information.
# ================================= Tool Message =================================
# Name: documentation_specialist
#
# Here's TechHub's **Return Policy**:
#
# ## Return Windows
# - **Unopened Electronics**: 30 days from delivery (original packaging/seals intact) → Full refund
# - **Opened Electronics**: 14 days from delivery (must be in working condition with all accessories included)
# - **All Other Items**: 30 days from delivery (must be in original condition)
#
# ## Condition Requirements
# Items must:
# - Be in good working condition with no physical damage
# - Include all original accessories (adapters, cables, manuals, etc.)
# - Show no signs of misuse or abuse
# - Have intact serial numbers and identification labels
# - Have minimal signs of use (for opened items)
#
# ## Non-Returnable Items
# - Clearance or final sale items
# - Digital gift cards
# - Downloadable software/digital products
# - Items marked "non-returnable" on product page
#
# ## Restocking Fees
# **No restocking fee** applies to:
# - Defective items (manufacturer defects or shipping damage)
# - Unopened items in original packaging
# - Items under $500
#
# Is there a specific aspect of the return policy you'd like more details about?
# ================================== Ai Message ==================================
#
# Great! Here's the information you requested:
#
# **Stock Status:** ✅ Yes, the **MacBook Air M2 (13-inch, 256GB)** is currently **in stock** and available for purchase at **$1,199.00**.
#
# **Processor:** The MacBook Air features an **Apple M2 chip**. This processor provides excellent performance with up to 18 hours of battery life and includes a fanless design for silent operation. It's well-suited for web browsing, video editing, and general professional work.
#
# **Return Policy:** We offer a flexible return policy:
# - **Unopened items**: 30 days for a full refund
# - **Opened items**: 14 days for returns (must be in working condition with all accessories)
#
# As long as the MacBook Air is in good working condition with no damage and all accessories included, you have 14 days to return it if opened, or 30 days if unopened. There's also no restocking fee for items under $500 or defective items.
#
# Would you like to proceed with a purchase, or do you have any other questions about the MacBook Air?
#
# 💡 Check LangSmith traces to see the parallel flow

# %% [markdown]
# **Sequential Execution Example:** Query that requires SEQUENTIAL agent execution - output from first agent feeds into second agent
#
# This demonstrates true agent orchestration where the supervisor can't parallelize!

# %%
print("Query 4: Requires SEQUENTIAL coordination (DB → Documents)")

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

result = supervisor_agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "I bought a monitor in my last order (ORD-2024-0063). Is the MacBook Air compatible with it?",
            }
        ]
    },
    config=config,
)

for message in result["messages"]:
    message.pretty_print()
print("\n💡 Check LangSmith traces to see SEQUENTIAL flow")
# Out:
# Query 4: Requires SEQUENTIAL coordination (DB → Documents)
# ================================ Human Message =================================
#
# I bought a monitor in my last order (ORD-2024-0063). Is the MacBook Air compatible with it?
# ================================== Ai Message ==================================
#
# [{'text': "I'll help you find out if the monitor from your order is compatible with a MacBook Air. Let me gather information about your order and then check the monitor's specifications.", 'type': 'text'}, {'id': 'toolu_01J3LnQGJNht5i37gk5hHg6g', 'input': {'query': 'Order details for ORD-2024-0063'}, 'name': 'database_specialist', 'type': 'tool_use'}, {'id': 'toolu_01SxrYPqLpM3zL5offrgrjkL', 'input': {'query': 'MacBook Air monitor compatibility requirements'}, 'name': 'documentation_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   database_specialist (toolu_01J3LnQGJNht5i37gk5hHg6g)
#  Call ID: toolu_01J3LnQGJNht5i37gk5hHg6g
#   Args:
#     query: Order details for ORD-2024-0063
#   documentation_specialist (toolu_01SxrYPqLpM3zL5offrgrjkL)
#  Call ID: toolu_01SxrYPqLpM3zL5offrgrjkL
#   Args:
#     query: MacBook Air monitor compatibility requirements
# ================================= Tool Message =================================
# Name: database_specialist
#
# **Order ORD-2024-0063 - Complete Details:**
#
# **Status:**
# - Status: Delivered
# - Order Date: July 13, 2024
# - Shipped Date: July 14, 2024
# - Tracking Number: 1Z999AA192518345
# - Total Amount: $543.74
#
# **Items:**
# - Product ID: TECH-MON-006
# - Quantity: 1
# - Price: $543.74
#
# The order has been delivered. Would you like me to get the product name and additional details for the item in this order?
# ================================= Tool Message =================================
# Name: documentation_specialist
#
# Based on the product documentation, here are the **MacBook Air monitor compatibility requirements**:
#
# ## Connection Options:
# - **USB-C monitors**: Direct connection via included USB-C cable (best option)
# - **HDMI monitors**: Requires a USB-C to HDMI adapter ($15-25)
# - **DisplayPort monitors**: Compatible with USB-C connection
#
# ## Key Specifications:
# - **Maximum resolution**: Up to 6K resolution supported
# - **Number of displays**: MacBook Air supports **one external display**
#
# ## Cable & Adapter Notes:
# - USB-C monitors often come with cables included
# - For HDMI or older monitors, adapters must be purchased separately
# - TechHub carries USB-C to HDMI adapters in the $15-25 price range
# - Thunderbolt ports (on some MacBooks) are backward compatible with USB-C
#
# ## Supported Monitor Types:
# - Any monitor with HDMI, DisplayPort, or USB-C input is compatible
# - Works with Dell, HP, Samsung, LG, and other brands
# - No special software or drivers required
#
# The documentation confirms that MacBook Air compatibility is very flexible—essentially any modern monitor can work with the appropriate adapter if needed.
# ================================== Ai Message ==================================
#
# [{'text': 'Now let me get the specific details about the monitor model you purchased:', 'type': 'text'}, {'id': 'toolu_01BeQttJfV8eoxmQTYfhXpMp', 'input': {'query': 'Product details for TECH-MON-006 - specs and connection type'}, 'name': 'database_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   database_specialist (toolu_01BeQttJfV8eoxmQTYfhXpMp)
#  Call ID: toolu_01BeQttJfV8eoxmQTYfhXpMp
#   Args:
#     query: Product details for TECH-MON-006 - specs and connection type
# ================================= Tool Message =================================
# Name: database_specialist
#
# Based on the database lookup, here are the details for **TECH-MON-006**:
#
# **Product:** Dell UltraSharp 27" 4K Monitor
#
# **Category:** Monitors
#
# **Price:** $549.00
#
# **Stock Status:** In Stock
#
# **Note:** The database returns the product name, category, price, and availability status. Detailed specifications (resolution, refresh rate, exact connection types like HDMI/DisplayPort/USB-C, color accuracy specs, etc.) are not available in the current database query results.
#
# To obtain those detailed technical specifications and connection type information, you would need to:
# - Check the manufacturer's product documentation or website
# - Request detailed specs from inventory management
# - Consult the product datasheet in your technical documentation system
#
# Is there other order or product information I can help you retrieve?
# ================================== Ai Message ==================================
#
# [{'text': 'Let me search for the specific technical specs of that Dell UltraSharp monitor:', 'type': 'text'}, {'id': 'toolu_01QKayPqaDxzmvcL8ViACQdg', 'input': {'query': 'Dell UltraSharp 27" 4K Monitor TECH-MON-006 specifications connection ports'}, 'name': 'documentation_specialist', 'type': 'tool_use'}]
# Tool Calls:
#   documentation_specialist (toolu_01QKayPqaDxzmvcL8ViACQdg)
#  Call ID: toolu_01QKayPqaDxzmvcL8ViACQdg
#   Args:
#     query: Dell UltraSharp 27" 4K Monitor TECH-MON-006 specifications connection ports
# ================================= Tool Message =================================
# Name: documentation_specialist
#
# Perfect! Here are the **connection ports specifications** for the Dell UltraSharp 27" 4K Monitor (TECH-MON-006):
#
# ### Connection Ports:
# - **1x HDMI 2.0** - Supports 4K at 60Hz
# - **1x DisplayPort 1.4** - Supports 4K at 60Hz
# - **1x USB-C** - Includes 65W Power Delivery (for charging compatible laptops)
# - **4x USB-A 3.2 downstream ports** - For connecting peripherals and USB devices
#
# ### Supported Resolutions:
# - **Native 4K (3840 x 2160)** at 60Hz via DisplayPort or USB-C
# - **4K at 60Hz** via HDMI 2.0
# - Automatically scales lower resolutions as needed
#
# ### Compatibility:
# - Works with macOS, Windows, Linux, and Chrome OS
# - Plug-and-play functionality (no driver installation required)
# - USB hub features require USB connection to computer
#
# The monitor also includes an included USB Type-B to Type-A upstream cable for USB hub functionality.
# ================================== Ai Message ==================================
#
# Great news! **Yes, the Dell UltraSharp 27" 4K Monitor from your order (ORD-2024-0063) is fully compatible with MacBook Air.** Here's why:
#
# **Connection Options:**
# - **USB-C Connection** - The monitor has a USB-C port with 65W Power Delivery, which is the most convenient option for MacBook Air. You can connect directly with a USB-C cable.
# - **Alternative Options** - It also has HDMI and DisplayPort connections if you prefer those with appropriate adapters.
#
# **Key Benefits:**
# - The monitor supports up to 4K resolution, which works great with MacBook Air
# - USB-C with Power Delivery means you can charge your MacBook Air while using the monitor
# - Plug-and-play functionality - no drivers needed
# - Includes a USB hub with 4 USB-A ports for additional peripherals
#
# **Setup Recommendation:**
# Simply connect the monitor to your MacBook Air using the USB-C port for the best experience - you'll get video display and charging capability all through one cable.
#
# Is there anything else you'd like to know about your monitor or MacBook Air setup?
#
# 💡 Check LangSmith traces to see SEQUENTIAL flow

# %% [markdown]
# #### 📦 Code Refactoring Note
#
# The agents we built in this section (Database Agent, Documents Agent, and Supervisor) have been **refactored into the `agents/` directory** as reusable factory functions:
#
# - `agents/db_agent.py` - Database Agent factory
# - `agents/docs_agent.py` - Documents Agent factory
# - `agents/supervisor_agent.py` - Supervisor Agent factory
#
# **Why factory functions?**
# - Fresh checkpointer for each instantiation (no state pollution)
# - Clean imports and reusability across notebooks
#
# In **Section 4**, we'll import these agents rather than redefining them:
# ```python
# from agents import create_db_agent, create_docs_agent, create_supervisor_agent
# ```
#
# This demonstrates how to architect reusable code! 🏗️

# %% [markdown]
# ### Key Takeaways
#
# #### What We Built
#
# 1. **Specialized Sub-Agents**
#    - Database Agent: Expert at structured data queries
#    - Documents Agent: Expert at document search
#    - Each agent has focused tools and expertise
#
# 2. **Supervisor Pattern**
#    - Sub-agents wrapped as tools (`@tool` decorator)
#    - Supervisor routes queries to appropriate specialist(s)
#    - Can orchestrate **parallel** or **sequential** coordination
#
# 3. **Coordination Patterns**
#    - **Simple routing**: Single agent handles entire query
#    - **Parallel coordination**: Multiple agents work independently on different parts
#    - **Sequential coordination**: Output from one agent feeds into another (true orchestration!)
#
# 4. **Benefits of Multi-Agent Architecture**
#    - **Separation of concerns** - Each agent has clear responsibility
#    - **Easier debugging** - Traces show which agent handled what
#    - **Maintainability** - Update one agent without affecting others
#    - **Scalability** - Easy to add new specialist agents
#
#
# #### Viewing Traces in LangSmith
#
# Go to your LangSmith project to see:
# - **Routing decisions** - Which agent(s) the supervisor called
# - **Tool executions** - What tools each agent used
# - **Message flow** - Complete conversation tree
# - **Timing** - How long each step took
# - **Sequential dependencies** - See when agents must run in order
#
# This visibility makes multi-agent systems much easier to debug!
#
# #### What's Next: Section 4
#
# In **Section 4**, we'll use **LangGraph primitives** to build even more sophisticated workflows:
# - Custom state management beyond messages
# - Conditional routing based on state
# - `interrupt()` for Human-in-the-Loop
# - Customer verification workflows
